# %% [markdown]
# # 3. Estimación de Pose (Los 6 Grados de Libertad)
#
# Aquí es donde ocurre la magia física. El ArUco no solo te da un centroide ($X, Y$), sino su orientación en el espacio.El Reto: Usando la calibración del ejercicio anterior, dibuja un eje 3D ($X, Y, Z$) sobre el marcador detectado. El eje debe rotar y moverse perfectamente con el papel.Por qué importa: Esto te otorga los 6 grados de libertad necesarios para estudiar la cinemática del robot con precisión.
