# %% [markdown]
# # 4. Duelo de Distancias: ArUco vs. Segmentación
#
# En tu tesis ya calculas la distancia mediante el área segmentada del cuadro rojo y la Ley del Cuadrado Inverso.  El Reto: Coloca un ArUco sobre tu objeto rojo. Compara la distancia ($Z$) que te entrega el ArUco frente a la distancia que estima tu modelo de área ($D_{est}$).  Por qué importa: Este ejercicio te servirá para tu Análisis del Error. Podrás ver si la incertidumbre del ArUco también crece de forma cuadrática como la de tu modelo actual.
